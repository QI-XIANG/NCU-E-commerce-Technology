# %%
#1
import pandas as pd
df = pd.read_excel("sales.xlsx",engine='openpyxl')

# %%
#2
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       65535 non-null  int64
#  1   Product    65535 non-null  object
#  2   line       65535 non-null  object
#  3   Product.1  65535 non-null  object
#  4   type       65535 non-null  object
#  5   Product.2  65535 non-null  object
#  6   Order      65535 non-null  object
#  7   method     61083 non-null  object
#  8   type.1     46709 non-null  object
#  9   Retailer   32525 non-null  object
#  10  country    24135 non-null  object
#  11  Revenue    21494 non-null  object
#  12  Planned    20925 non-null  object
#  13  revenue    20645 non-null  object
#  14  Product.3  20588 non-null  object
#  15  cost       19224 non-null  float64
#  16  Quantity   13663 non-null  float64
#  17  Unit       7046 non-null   float64
#  18  cost.1     2403 non-null   float64
# ...

# %%
#3
correct_title = []
temp = ''
for i in df.columns:
    if i.istitle():
        if 'Product' in i:
            i = 'Product'
        if 'Unit' in i:
            i = 'Unit'
        correct_title.append(temp)
        temp = ''
        temp += i
    if i.islower():
        if 'type' in i:
            i = 'type'
        if 'cost' in i:
            i = 'cost'
        temp += ' '
        temp += i

correct_title[1:]
# Out:
# ['Year',
#  'Product line',
#  'Product type',
#  'Product',
#  'Order method type',
#  'Retailer country',
#  'Revenue',
#  'Planned revenue',
#  'Product cost',
#  'Quantity',
#  'Unit cost',
#  'Unit price',
#  'Gross profit']

# %%
df.head()
# Out:
#    Year  Product       line Product.1  type  Product.2  Order method  \
# 0  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 1  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 2  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 3  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 4  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
#
#       type.1 Retailer  ...  Quantity        Unit    cost.1 Unit.1 price  \
# 0  Telephone   United  ...      6.59  156672.570  5.195714    NaN   NaN
# 1  Telephone   Canada  ...   7145.88       6.190       NaN    NaN   NaN
# 2  Telephone   Mexico  ...       NaN         NaN       NaN    NaN   NaN
# 3  Telephone   Brazil  ...       NaN         NaN       NaN    NaN   NaN
# 4  Telephone    Japan  ...  91707.18       5.488       NaN    NaN   NaN
#
#    Gross  profit  Unit.2  sale  price.1
# 0    NaN     NaN     NaN   NaN      NaN
# ...

# %%
#4
print(df.groupby('Year').size())
print()
print(df.groupby(['Year','Product']).size())
'''
經過比對Year欄位沒有錯置的問題
'''
# Out:
# Year
# 2004    21168
# 2005    21168
# 2006    21168
# 2007     2031
# dtype: int64
#
# Year  Product
# 2004  Camping           6027
#       Golf              2205
#       Mountaineering    3087
#       Outdoor           2205
#       Personal          7644
# 2005  Camping           6027
#       Golf              2205
#       Mountaineering    3087
#       Outdoor           2205
#       Personal          7644
# 2006  Camping           6027
#       Golf              2205
#       Mountaineering    3087
#       Outdoor           2205
#       Personal          7644
# 2007  Camping           2031
# dtype: int64
# '\n經過比對Year欄位沒有錯置的問題\n'

# %%
#5
print(df.groupby(['Product','line']).size())
print()
print(df.groupby(['Product','line','Product.1']).size())
'''
經過比對Product和line欄位沒有錯置的問題，
可以直接合併欄位。
'''
df['Product line'] = df['Product'] + ' ' + df['line']
df = df.drop(['Product','line'],axis=1)
df
# Out:
# Product         line
# Camping         Equipment      20112
# Golf            Equipment       6615
# Mountaineering  Equipment       9261
# Outdoor         Protection      6615
# Personal        Accessories    22932
# dtype: int64
#
# Product         line         Product.1
# Camping         Equipment    Cooking       5880
#                              Lanterns      5292
#                              Packs         2646
#                              Sleeping      3087
#                              Tents         3207
# Golf            Equipment    Golf          1764
#                              Irons         1764
#                              Putters       1323
#                              Woods         1764
# Mountaineering  Equipment    Climbing      3087
#                              Rope          1764
#                              Safety        1764
#                              Tools         2646
# Outdoor         Protection   First         2205
# ...

# %%
#6
'''data_type = ['Climbing','Cooking','First','Golf','Insect','Sleeping']'''
df_new_title = df.rename(columns={'Product.1': 'Product'})
df_new_title
'''
透過判斷產品字根移除不需要的Product type
'''
df1 = df_new_title[(df_new_title.Product == 'Climbing') | (df_new_title.Product == 'Cooking') | (df_new_title.Product == 'First') | (df_new_title.Product == 'Golf') | (df_new_title.Product == 'Insect') | (df_new_title.Product == 'Sleeping')]
'''
確認Product Type 的欄位錯置狀況
'''
print(df1.groupby(['Product','type']).size())
print('='*50)
print(df1.groupby(['Product','type','Product.2']).size())
'''
經過觀查可以發現Product Type剛好被分別放在Product、type中並各佔一個欄位，
故可以在下一題直接合併欄位，接下來先覆蓋原來的df
'''
print('='*50)
df = df1
df
# Out:
# Product   type
# Climbing  Accessories    3087
# Cooking   Gear           5880
# First     Aid            2205
# Golf      Accessories    1764
# Insect    Repellents     2205
# Sleeping  Bags           3087
# dtype: int64
# ...
# Product   type         Product.2
# Climbing  Accessories  Firefly       1323
#                        Granite       1764
# Cooking   Gear         TrailChef     5880
# First     Aid          Aloe           441
#                        Calamine       441
#                        Compact        441
#                        Deluxe         441
#                        Insect         441
# Golf      Accessories  Course        1764
# Insect    Repellents   BugShield     2205
# Sleeping  Bags         Hibernator    3087
# dtype: int64
# ...
#        Year  Product  type  Product.2     Order method       type.1 Retailer  \
# 0      2004  Cooking  Gear  TrailChef     Water    Bag    Telephone   United
# 1      2004  Cooking  Gear  TrailChef     Water    Bag    Telephone   Canada
# ...

# %%
#7 
'''在第六題我們已經成功移除不必要的資料，同時也確認欄位可以直接進行合併並drop掉不要的欄位'''
df1['Product type'] = df1['Product'] + ' ' + df1['type']
df1 = df1.drop(['Product','type'],axis=1)
df = df1
df
# Out:
# C:\Users\QiXiang\.conda\envs\Test\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        Year  Product.2     Order method       type.1 Retailer    country  \
# 0      2004  TrailChef     Water    Bag    Telephone   United     States
# 1      2004  TrailChef     Water    Bag    Telephone   Canada   13444.68
# 2      2004  TrailChef     Water    Bag    Telephone   Mexico        NaN
# 3      2004  TrailChef     Water    Bag    Telephone   Brazil        NaN
# 4      2004  TrailChef     Water    Bag    Telephone    Japan  181120.24
# ...     ...        ...       ...    ...          ...      ...        ...
# ...

# %%
#8.1 
'''
前置判斷Product分別有佔1~3個欄位的狀況出現，甚至還不只
'''
print(df.groupby(['Product.2','Order']).size())
print('='*50)
print(df.groupby(['Product.2','Order','method']).size())
print('='*50)
print(df.groupby(['Product.2','Order','method','type.1']).size())
print('='*50)
print(df.groupby(['Product.2','Order','method','Retailer']).size())
# Out:
# Product.2   Order
# Aloe        Relief           441
# BugShield   Extreme          441
#             Lotion           882
#             Natural          441
#             Spray            441
# Calamine    Relief           441
# Compact     Relief           441
# Course      Pro             1764
# Deluxe      Family           441
# Firefly     Charger          441
#             Climbing         441
#             Rechargeable     441
# Granite     Belay            441
#             Carabiner        441
#             Chalk            441
#             Pulley           441
# Hibernator  Camp             441
#             E-mail            63
#             Extreme          441
#             Fax               63
#             Lite             441
#             Mail              63
#             Pad              441
#             Pillow           441
#             Sales             63
#             Self             441
#             Special           63
#             Telephone         63
# ...

# %%
#8.2
'''
將Product欄位切成p1、p2、p3、...來處理
'''
purchase_type = ['E-mail','Fax','Mail','Sales','Special','Telephone','Web']
p1 = df[df['Order'].isin(purchase_type)].copy(deep=True) #Product名稱佔1個欄位的
p2 = df[df['method'].isin(purchase_type)].copy(deep=True)
p3 = df[df['type.1'].isin(purchase_type)].copy(deep=True)
p4 = df[df['Retailer'].isin(purchase_type)].copy(deep=True)
p5 = df[df['country'].isin(purchase_type)].copy(deep=True)
p6 = df[df['Revenue'].isin(purchase_type)].copy(deep=True)
'''經過測試確認Product名稱總共橫跨1-6個欄位'''
p7 = df[df['Planned'].isin(purchase_type)].copy(deep=True) #空的
print(len(p1)+len(p2)+len(p3)+len(p4)+len(p5)+len(p6))
# Out:
# 18228

# %%
#8.3 
'''處理p1的欄位合併'''
p1['Product'] = p1['Product.2']
'''處理p2的欄位合併'''
p2['Product'] = p2['Product.2'] + ' ' + p2['Order']
'''處理p3的欄位合併'''
p3['Product'] = p3['Product.2'] + ' ' + p3['Order'] + ' ' + p3['method']
'''處理p4的欄位合併'''
p4['Product'] = p4['Product.2'] + ' ' + p4['Order'] + ' ' + p4['method'] + ' ' + p4['type.1']
'''處理p5的欄位合併'''
p5['Product'] = str(p5['Product.2']) + ' ' + str(p5['Order']) + ' ' + str(p5['method']) + ' ' + str(p5['type.1']) + ' ' + str(p5['Retailer'])
'''處理p6的欄位合併'''
p6['Product'] = p6['Product.2'] + ' ' + p6['Order'] + ' ' + p6['method'] + ' ' + p6['type.1'] + ' ' + p6['Retailer'] + ' ' + p6['country']
'''將值指定回df'''
df = pd.concat([p1,p2,p3,p4,p5,p6])
print(df.groupby('Product type').size())
print('='*50)
df
# Out:
# Product type
# Climbing Accessories    3087
# Cooking Gear            5880
# First Aid               2205
# Golf Accessories        1764
# Insect Repellents       2205
# Sleeping Bags           3087
# dtype: int64
# ...
#        Year   Product.2      Order  method    type.1   Retailer  country  \
# 2499   2004  Hibernator  Telephone  United    States  968870.75  1130591
# 2500   2004  Hibernator  Telephone  Canada       NaN        NaN      NaN
# 2501   2004  Hibernator  Telephone  Mexico  26627.25   28631.85    16770
# 2502   2004  Hibernator  Telephone  Brazil       NaN        NaN      NaN
# 2503   2004  Hibernator  Telephone   Japan  624588.8  720054.32   421744
# ...     ...         ...        ...     ...       ...        ...      ...
# 59971  2006      Course        Pro    Golf       and        Tee      Set
# 59972  2006      Course        Pro    Golf       and        Tee      Set
# 59973  2006      Course        Pro    Golf       and        Tee      Set
# ...

# %%
#9.1
'''接續之前的p1~p6繼續處理'''
purchase_type = ['E-mail','Fax','Mail','Sales','Special','Telephone','Web']
p1_r1 = p1[p1['Order']!= 'Sales'].copy(deep=True)
p1_r2 = p1[p1['method'] == 'visit'].copy(deep=True)
p2_r1 = p2[p2['method']!= 'Sales'].copy(deep=True)
p2_r2 = p2[p2["type.1"]=='visit'].copy(deep=True)
p3_r1 = p3[p3['type.1'] != 'Sales'].copy(deep=True)
p3_r2 = p3[p3['Retailer'] == 'visit'].copy(deep=True)
p4_r1 = p4[p4['Retailer'] != 'Sales'].copy(deep=True)
p4_r2 = p4[p4['country'] == 'visit'].copy(deep=True)
p5_r1 = p5[p5['country'] != 'Sales'].copy(deep=True)
p5_r2 = p5[p5['Revenue'] == 'visit'].copy(deep=True)
p6_r1 = p6[p6['Revenue'] != 'Sales'].copy(deep=True)
p6_r2 = p6[p6['Planned'] == 'visit'].copy(deep=True)

# %%
#9.2
'''產生對的Order method type.1並接起來'''
p1_r1['Order method type'] = p1_r1['Order']
p1_r2['Order method type'] = p1_r2['Order'] + ' ' +  p1_r2['method']
p2_r1['Order method type'] = p2_r1['method']
p2_r2['Order method type'] = p2_r2['method'] + ' ' +  p2_r2['type.1']
p3_r1['Order method type'] = p3_r1['type.1']
p3_r2['Order method type'] = p3_r2['type.1'] + ' ' +  p3_r2['Retailer']
p4_r1['Order method type'] = p4_r1['Retailer']
p4_r2['Order method type'] = p4_r2['Retailer'] + ' ' +  p4_r2['country']
p5_r1['Order method type'] = p5_r1['country']
p5_r2['Order method type'] = p5_r2['country'] + ' ' +  p5_r2['Revenue']
p6_r1['Order method type'] = p6_r1['Revenue']
p6_r2['Order method type'] = p6_r2['Revenue'] + ' ' +  p6_r2['Planned']
p1_new = pd.concat([p1_r1,p1_r2,p2_r1,p2_r2,p3_r1,p3_r2,p4_r1,p4_r2,p5_r1,p5_r2,p6_r1,p6_r2])
print(p1_new.groupby('Order method type').size())
df = p1_new
df
# Out:
# Order method type
# E-mail         2604
# Fax            2604
# Mail           2604
# Sales visit    2604
# Special        2604
# Telephone      2604
# Web            2604
# dtype: int64
#        Year   Product.2      Order  method    type.1   Retailer  country  \
# 2499   2004  Hibernator  Telephone  United    States  968870.75  1130591
# 2500   2004  Hibernator  Telephone  Canada       NaN        NaN      NaN
# 2501   2004  Hibernator  Telephone  Mexico  26627.25   28631.85    16770
# 2502   2004  Hibernator  Telephone  Brazil       NaN        NaN      NaN
# 2503   2004  Hibernator  Telephone   Japan  624588.8  720054.32   421744
# ...     ...         ...        ...     ...       ...        ...      ...
# 59866  2006      Course        Pro    Golf       and        Tee      Set
# 59867  2006      Course        Pro    Golf       and        Tee      Set
# 59868  2006      Course        Pro    Golf       and        Tee      Set
# ...

# %%
print(p2.groupby('Order').size())
print('='*55)
print(p2.groupby('method').size())
print('='*55)
print(p2.groupby('type.1').size())

p2[p2["type.1"]=='visit']
# Out:
# Order
# Belay        441
# Canteen      588
# Carabiner    441
# Charger      441
# Cup          588
# Extreme      882
# Kettle       588
# Lite         441
# Lotion       441
# Natural      441
# Pad          441
# Pillow       441
# Pulley       441
# Relief       882
# Spray        441
# Utensils     588
# dtype: int64
# ...
# method
# E-mail       1218
# Fax          1218
# Mail         1218
# Sales        1218
# Special      1218
# Telephone    1218
# Web          1218
# dtype: int64
# ...
# type.1
# Australia       348
# Austria         348
# Belgium         348
# Brazil          348
# Canada          348
# China           348
# Denmark         348
# Finland         348
# France          348
# Germany         348
# Italy           348
# Japan           348
# Korea           348
# Mexico          348
# Netherlands     348
# Singapore       348
# Spain           348
# Sweden          348
# Switzerland     348
# United          696
# visit          1218
# dtype: int64
# ...

# %%
#10.1
'''接續之前的p1_r1~p6_r2繼續處理'''
col = ["method","type.1","Retailer","country","Revenue","Planned"]
p1_r1_c1 = p1_r1[p1_r1['method'] != 'United'].copy(deep=True)
p1_r1_c2 = p1_r1[p1_r1['method'] == 'United'].copy(deep=True)
p1_r2_c1 = p1_r2[p1_r2['type.1'] != 'United'].copy(deep=True)
p1_r2_c2 = p1_r2[p1_r2['type.1'] == 'United'].copy(deep=True)
#############################################################
p2_r1_c1 = p2_r1[p2_r1['type.1'] != 'United'].copy(deep=True)
p2_r1_c2 = p2_r1[p2_r1['type.1'] == 'United'].copy(deep=True)
p2_r2_c1 = p2_r2[p2_r2['Retailer'] != 'United'].copy(deep=True)
p2_r2_c2 = p2_r2[p2_r2['Retailer'] == 'United'].copy(deep=True)
#############################################################
p3_r1_c1 = p3_r1[p3_r1['Retailer'] != 'United'].copy(deep=True)
p3_r1_c2 = p3_r1[p3_r1['Retailer'] == 'United'].copy(deep=True)
p3_r2_c1 = p3_r2[p3_r2['country'] != 'United'].copy(deep=True)
p3_r2_c2 = p3_r2[p3_r2['country'] == 'United'].copy(deep=True)
#############################################################
p4_r1_c1 = p4_r1[p4_r1['country'] != 'United'].copy(deep=True)
p4_r1_c2 = p4_r1[p4_r1['country'] == 'United'].copy(deep=True)
p4_r2_c1 = p4_r2[p4_r2['Revenue'] != 'United'].copy(deep=True)
p4_r2_c2 = p4_r2[p4_r2['Revenue'] == 'United'].copy(deep=True)
#############################################################
p5_r1_c1 = p5_r1[p5_r1['Revenue'] != 'United'].copy(deep=True)
p5_r1_c2 = p5_r1[p5_r1['Revenue'] == 'United'].copy(deep=True)
p5_r2_c1 = p5_r2[p5_r2['Planned'] != 'United'].copy(deep=True)
p5_r2_c2 = p5_r2[p5_r2['Planned'] == 'United'].copy(deep=True)
#############################################################
p6_r1_c1 = p6_r1[p6_r1['Planned'] != 'United'].copy(deep=True)
p6_r1_c2 = p6_r1[p6_r1['Planned'] == 'United'].copy(deep=True)
p6_r2_c1 = p6_r2[p6_r2['revenue'] != 'United'].copy(deep=True)
p6_r2_c2 = p6_r2[p6_r2['revenue'] == 'United'].copy(deep=True)
#############################################################

# %%
p1[p1['Order']!= 'Sales']
# Out:
#        Year   Product.2      Order       method    type.1   Retailer  country  \
# 2499   2004  Hibernator  Telephone       United    States  968870.75  1130591
# 2500   2004  Hibernator  Telephone       Canada       NaN        NaN      NaN
# 2501   2004  Hibernator  Telephone       Mexico  26627.25   28631.85    16770
# 2502   2004  Hibernator  Telephone       Brazil       NaN        NaN      NaN
# 2503   2004  Hibernator  Telephone        Japan  624588.8  720054.32   421744
# ...     ...         ...        ...          ...       ...        ...      ...
# 44977  2006  Hibernator        Fax      Belgium       NaN        NaN      NaN
# 44978  2006  Hibernator        Fax  Switzerland       NaN        NaN      NaN
# 44979  2006  Hibernator        Fax      Austria       NaN        NaN      NaN
# 44980  2006  Hibernator        Fax        Italy       NaN        NaN      NaN
# 44981  2006  Hibernator        Fax        Spain  74348.17   78260.39    45838
#
# ...

# %%
#10.2
p1_r1_c1["Retailer Country"] = p1_r1_c1["method"]
p1_r1_c2["Retailer Country"] = p1_r1_c2["method"] + ' ' + p1_r1_c2["type.1"]
p1_r2_c1["Retailer Country"] = p1_r2_c1["type.1"]
p1_r2_c2["Retailer Country"] = p1_r2_c2["type.1"] + ' ' + p1_r2_c2["Retailer"]
#############################################################
p2_r1_c1["Retailer Country"] = p2_r1_c1["type.1"]
p2_r1_c2["Retailer Country"] = p2_r1_c2["type.1"] + ' ' + p2_r1_c2["Retailer"]
p2_r2_c1["Retailer Country"] = p2_r2_c1["Retailer"]
p2_r2_c2["Retailer Country"] = p2_r2_c2["Retailer"] + ' ' + p2_r2_c2["country"]
#############################################################
p3_r1_c1["Retailer Country"] = p3_r1_c1["Retailer"]
p3_r1_c2["Retailer Country"] = p3_r1_c2["Retailer"] + ' ' + p3_r1_c2["country"]
p3_r2_c1["Retailer Country"] = p3_r2_c1["country"]
p3_r2_c2["Retailer Country"] = p3_r2_c2["country"] + ' ' + p3_r2_c2["Revenue"]
#############################################################
p4_r1_c1["Retailer Country"] = p4_r1_c1["country"]
p4_r1_c2["Retailer Country"] = p4_r1_c2["country"] + ' ' + p4_r1_c2["Revenue"]
p4_r2_c1["Retailer Country"] = p4_r2_c1["Revenue"]
p4_r2_c2["Retailer Country"] = p4_r2_c2["Revenue"] + ' ' + p4_r2_c2["Planned"]
#############################################################
p5_r1_c1["Retailer Country"] = p5_r1_c1["Revenue"]
p5_r1_c2["Retailer Country"] = p5_r1_c2["Revenue"] + ' ' + p5_r1_c2["Planned"]
p5_r2_c1["Retailer Country"] = p5_r2_c1["Planned"]
p5_r2_c2["Retailer Country"] = p5_r2_c2["Planned"] + ' ' + p5_r2_c2["revenue"]
#############################################################
p6_r1_c1["Retailer Country"] = p6_r1_c1["Planned"]
p6_r1_c2["Retailer Country"] = p6_r1_c2["Planned"] + ' ' + p6_r1_c2["revenue"]
p6_r2_c1["Retailer Country"] = p6_r2_c1["revenue"]
p6_r2_c2["Retailer Country"] = p6_r2_c2["revenue"] + ' ' + p6_r2_c2["Product.3"]
#############################################################


p8_new = pd.concat([p1_r1_c1,p1_r1_c2,p1_r2_c1,p1_r2_c2,
                    p2_r1_c1,p2_r1_c2,p2_r2_c1,p2_r2_c2,
                    p3_r1_c1,p3_r1_c2,p3_r2_c1,p3_r2_c2,
                    p4_r1_c1,p4_r1_c2,p4_r2_c1,p4_r2_c2,
                    p5_r1_c1,p5_r1_c2,p5_r2_c1,p5_r2_c2,
                    p6_r1_c1,p6_r1_c2,p6_r2_c1,p6_r2_c2,])

#覆蓋原有的df，處理完RRetailer Country
df = p8_new
df
# Out:
#        Year   Product.2      Order  method    type.1   Retailer country  \
# 2500   2004  Hibernator  Telephone  Canada       NaN        NaN     NaN
# 2501   2004  Hibernator  Telephone  Mexico  26627.25   28631.85   16770
# 2502   2004  Hibernator  Telephone  Brazil       NaN        NaN     NaN
# 2503   2004  Hibernator  Telephone   Japan  624588.8  720054.32  421744
# 2504   2004  Hibernator  Telephone   Korea       NaN        NaN     NaN
# ...     ...         ...        ...     ...       ...        ...     ...
# 17529  2004      Course        Pro    Golf       and        Tee     Set
# 38682  2005      Course        Pro    Golf       and        Tee     Set
# 38697  2005      Course        Pro    Golf       and        Tee     Set
# 59850  2006      Course        Pro    Golf       and        Tee     Set
# 59865  2006      Course        Pro    Golf       and        Tee     Set
#
#       Revenue Planned revenue  ...     Gross  profit  Unit.2  sale  price.1  \
# ...

# %%
#11.1 
#處理剩下的欄位 -- Revenue
p1_r1_c1["Revenue.111"] = p1_r1_c1["type.1"]
p1_r1_c2["Revenue.111"] = p1_r1_c2["Retailer"]
p1_r2_c1["Revenue.111"] = p1_r2_c1["Retailer"]
p1_r2_c2["Revenue.111"] = p1_r2_c2['country']
#############################################################
p2_r1_c1["Revenue.111"] = p2_r1_c1["Retailer"]
p2_r1_c2["Revenue.111"] = p2_r1_c2["country"]
p2_r2_c1["Revenue.111"] = p2_r2_c1["country"]
p2_r2_c2["Revenue.111"] = p2_r2_c2["Revenue"]
#############################################################
p3_r1_c1["Revenue.111"] = p3_r1_c1["country"]
p3_r1_c2["Revenue.111"] = p3_r1_c2["Revenue"]
p3_r2_c1["Revenue.111"] = p3_r2_c1["Revenue"]
p3_r2_c2["Revenue.111"] = p3_r2_c2["Planned"]
#############################################################
p4_r1_c1["Revenue.111"] = p4_r1_c1["Revenue"]
p4_r1_c2["Revenue.111"] = p4_r1_c2["Planned"]
p4_r2_c1["Revenue.111"] = p4_r2_c1["Planned"]
p4_r2_c2["Revenue.111"] = p4_r2_c2["revenue"]
#############################################################
p5_r1_c1["Revenue.111"] = p5_r1_c1["Planned"]
p5_r1_c2["Revenue.111"] = p5_r1_c2["revenue"]
p5_r2_c1["Revenue.111"] = p5_r2_c1["revenue"]
p5_r2_c2["Revenue.111"] = p5_r2_c2["Product.3"]
#############################################################
p6_r1_c1["Revenue.111"] = p6_r1_c1["revenue"]
p6_r1_c2["Revenue.111"] = p6_r1_c2["Product.3"]
p6_r2_c1["Revenue.111"] = p6_r2_c1["Product.3"]
p6_r2_c2["Revenue.111"] = p6_r2_c2["cost"]
#############################################################

# %%
p10_new = pd.concat([p1_r1_c1,p1_r1_c2,p1_r2_c1,p1_r2_c2,
                    p2_r1_c1,p2_r1_c2,p2_r2_c1,p2_r2_c2,
                    p3_r1_c1,p3_r1_c2,p3_r2_c1,p3_r2_c2,
                    p4_r1_c1,p4_r1_c2,p4_r2_c1,p4_r2_c2,
                    p5_r1_c1,p5_r1_c2,p5_r2_c1,p5_r2_c2,
                    p6_r1_c1,p6_r1_c2,p6_r2_c1,p6_r2_c2,])
p10_new
# Out:
#        Year   Product.2      Order  method    type.1   Retailer country  \
# 2500   2004  Hibernator  Telephone  Canada       NaN        NaN     NaN
# 2501   2004  Hibernator  Telephone  Mexico  26627.25   28631.85   16770
# 2502   2004  Hibernator  Telephone  Brazil       NaN        NaN     NaN
# 2503   2004  Hibernator  Telephone   Japan  624588.8  720054.32  421744
# 2504   2004  Hibernator  Telephone   Korea       NaN        NaN     NaN
# ...     ...         ...        ...     ...       ...        ...     ...
# 17529  2004      Course        Pro    Golf       and        Tee     Set
# 38682  2005      Course        Pro    Golf       and        Tee     Set
# 38697  2005      Course        Pro    Golf       and        Tee     Set
# 59850  2006      Course        Pro    Golf       and        Tee     Set
# 59865  2006      Course        Pro    Golf       and        Tee     Set
#
#       Revenue Planned revenue  ... profit  Unit.2  sale  price.1  \
# ...

# %%
#11.2
#處理剩下的欄位 -- Planned revenue
p1_r1_c1["Planned revenue"] = p1_r1_c1["Retailer"]
p1_r1_c2["Planned revenue"] = p1_r1_c2["country"]
p1_r2_c1["Planned revenue"] = p1_r2_c1["country"]
p1_r2_c2["Planned revenue"] = p1_r2_c2['Revenue']
#############################################################
p2_r1_c1["Planned revenue"] = p2_r1_c1["country"]
p2_r1_c2["Planned revenue"] = p2_r1_c2["Revenue"]
p2_r2_c1["Planned revenue"] = p2_r2_c1["Revenue"]
p2_r2_c2["Planned revenue"] = p2_r2_c2["Planned"]
#############################################################
p3_r1_c1["Planned revenue"] = p3_r1_c1["Revenue"]
p3_r1_c2["Planned revenue"] = p3_r1_c2["Planned"]
p3_r2_c1["Planned revenue"] = p3_r2_c1["Planned"]
p3_r2_c2["Planned revenue"] = p3_r2_c2["revenue"]
#############################################################
p4_r1_c1["Planned revenue"] = p4_r1_c1["Planned"]
p4_r1_c2["Planned revenue"] = p4_r1_c2["revenue"]
p4_r2_c1["Planned revenue"] = p4_r2_c1["revenue"]
p4_r2_c2["Planned revenue"] = p4_r2_c2["Product.3"]
#############################################################
p5_r1_c1["Planned revenue"] = p5_r1_c1["revenue"]
p5_r1_c2["Planned revenue"] = p5_r1_c2["Product.3"]
p5_r2_c1["Planned revenue"] = p5_r2_c1["Product.3"]
p5_r2_c2["Planned revenue"] = p5_r2_c2["cost"]
#############################################################
p6_r1_c1["Planned revenue"] = p6_r1_c1["Product.3"]
p6_r1_c2["Planned revenue"] = p6_r1_c2["cost"]
p6_r2_c1["Planned revenue"] = p6_r2_c1["cost"]
p6_r2_c2["Planned revenue"] = p6_r2_c2["Quantity"]
#############################################################

# %%
p10_new = pd.concat([p1_r1_c1,p1_r1_c2,p1_r2_c1,p1_r2_c2,
                    p2_r1_c1,p2_r1_c2,p2_r2_c1,p2_r2_c2,
                    p3_r1_c1,p3_r1_c2,p3_r2_c1,p3_r2_c2,
                    p4_r1_c1,p4_r1_c2,p4_r2_c1,p4_r2_c2,
                    p5_r1_c1,p5_r1_c2,p5_r2_c1,p5_r2_c2,
                    p6_r1_c1,p6_r1_c2,p6_r2_c1,p6_r2_c2,])
p10_new
# Out:
#        Year   Product.2      Order  method    type.1   Retailer country  \
# 2500   2004  Hibernator  Telephone  Canada       NaN        NaN     NaN
# 2501   2004  Hibernator  Telephone  Mexico  26627.25   28631.85   16770
# 2502   2004  Hibernator  Telephone  Brazil       NaN        NaN     NaN
# 2503   2004  Hibernator  Telephone   Japan  624588.8  720054.32  421744
# 2504   2004  Hibernator  Telephone   Korea       NaN        NaN     NaN
# ...     ...         ...        ...     ...       ...        ...     ...
# 17529  2004      Course        Pro    Golf       and        Tee     Set
# 38682  2005      Course        Pro    Golf       and        Tee     Set
# 38697  2005      Course        Pro    Golf       and        Tee     Set
# 59850  2006      Course        Pro    Golf       and        Tee     Set
# 59865  2006      Course        Pro    Golf       and        Tee     Set
#
#       Revenue Planned revenue  ... Unit.2  sale  price.1       Product line  \
# ...

# %%
#11.3
#處理剩下的欄位 -- Product cost
p1_r1_c1["Product cost"] = p1_r1_c1["country"]
p1_r1_c2["Product cost"] = p1_r1_c2["Revenue"]
p1_r2_c1["Product cost"] = p1_r2_c1["Revenue"]
p1_r2_c2["Product cost"] = p1_r2_c2['Planned']
#############################################################
p2_r1_c1["Product cost"] = p2_r1_c1["Revenue"]
p2_r1_c2["Product cost"] = p2_r1_c2["Planned"]
p2_r2_c1["Product cost"] = p2_r2_c1["Planned"]
p2_r2_c2["Product cost"] = p2_r2_c2["revenue"]
#############################################################
p3_r1_c1["Product cost"] = p3_r1_c1["Planned"]
p3_r1_c2["Product cost"] = p3_r1_c2["revenue"]
p3_r2_c1["Product cost"] = p3_r2_c1["revenue"]
p3_r2_c2["Product cost"] = p3_r2_c2["Product.3"]
#############################################################
p4_r1_c1["Product cost"] = p4_r1_c1["revenue"]
p4_r1_c2["Product cost"] = p4_r1_c2["Product.3"]
p4_r2_c1["Product cost"] = p4_r2_c1["Product.3"]
p4_r2_c2["Product cost"] = p4_r2_c2["cost"]
#############################################################
p5_r1_c1["Product cost"] = p5_r1_c1["Product.3"]
p5_r1_c2["Product cost"] = p5_r1_c2["cost"]
p5_r2_c1["Product cost"] = p5_r2_c1["cost"]
p5_r2_c2["Product cost"] = p5_r2_c2["Quantity"]
#############################################################
p6_r1_c1["Product cost"] = p6_r1_c1["cost"]
p6_r1_c2["Product cost"] = p6_r1_c2["Quantity"]
p6_r2_c1["Product cost"] = p6_r2_c1["Quantity"]
p6_r2_c2["Product cost"] = p6_r2_c2["Unit"]
#############################################################

# %%
#11.4
#處理剩下的欄位 -- Quantity
p1_r1_c1["Quantity.111"] = p1_r1_c1["Revenue"]
p1_r1_c2["Quantity.111"] = p1_r1_c2["Planned"]
p1_r2_c1["Quantity.111"] = p1_r2_c1["Planned"]
p1_r2_c2["Quantity.111"] = p1_r2_c2['revenue']
#############################################################
p2_r1_c1["Quantity.111"] = p2_r1_c1["Planned"]
p2_r1_c2["Quantity.111"] = p2_r1_c2["revenue"]
p2_r2_c1["Quantity.111"] = p2_r2_c1["revenue"]
p2_r2_c2["Quantity.111"] = p2_r2_c2["Product.3"]
#############################################################
p3_r1_c1["Quantity.111"] = p3_r1_c1["revenue"]
p3_r1_c2["Quantity.111"] = p3_r1_c2["Product.3"]
p3_r2_c1["Quantity.111"] = p3_r2_c1["Product.3"]
p3_r2_c2["Quantity.111"] = p3_r2_c2["cost"]
#############################################################
p4_r1_c1["Quantity.111"] = p4_r1_c1["Product.3"]
p4_r1_c2["Quantity.111"] = p4_r1_c2["cost"]
p4_r2_c1["Quantity.111"] = p4_r2_c1["cost"]
p4_r2_c2["Quantity.111"] = p4_r2_c2["Quantity"]
#############################################################
p5_r1_c1["Quantity.111"] = p5_r1_c1["cost"]
p5_r1_c2["Quantity.111"] = p5_r1_c2["Quantity"]
p5_r2_c1["Quantity.111"] = p5_r2_c1["Quantity"]
p5_r2_c2["Quantity.111"] = p5_r2_c2["Unit"]
#############################################################
p6_r1_c1["Quantity.111"] = p6_r1_c1["Quantity"]
p6_r1_c2["Quantity.111"] = p6_r1_c2["Unit"]
p6_r2_c1["Quantity.111"] = p6_r2_c1["Unit"]
p6_r2_c2["Quantity.111"] = p6_r2_c2["cost.1"]
#############################################################

# %%
p10_new = pd.concat([p1_r1_c1,p1_r1_c2,p1_r2_c1,p1_r2_c2,
                    p2_r1_c1,p2_r1_c2,p2_r2_c1,p2_r2_c2,
                    p3_r1_c1,p3_r1_c2,p3_r2_c1,p3_r2_c2,
                    p4_r1_c1,p4_r1_c2,p4_r2_c1,p4_r2_c2,
                    p5_r1_c1,p5_r1_c2,p5_r2_c1,p5_r2_c2,
                    p6_r1_c1,p6_r1_c2,p6_r2_c1,p6_r2_c2,])
p10_new
# Out:
#        Year   Product.2      Order  method    type.1   Retailer country  \
# 2500   2004  Hibernator  Telephone  Canada       NaN        NaN     NaN
# 2501   2004  Hibernator  Telephone  Mexico  26627.25   28631.85   16770
# 2502   2004  Hibernator  Telephone  Brazil       NaN        NaN     NaN
# 2503   2004  Hibernator  Telephone   Japan  624588.8  720054.32  421744
# 2504   2004  Hibernator  Telephone   Korea       NaN        NaN     NaN
# ...     ...         ...        ...     ...       ...        ...     ...
# 17529  2004      Course        Pro    Golf       and        Tee     Set
# 38682  2005      Course        Pro    Golf       and        Tee     Set
# 38697  2005      Course        Pro    Golf       and        Tee     Set
# 59850  2006      Course        Pro    Golf       and        Tee     Set
# 59865  2006      Course        Pro    Golf       and        Tee     Set
#
#       Revenue Planned revenue  ... price.1       Product line  \
# ...

# %%
p10_new.groupby('Product type').count()
# Out:
#                       Year  Product.2  Order  method  type.1  Retailer  \
# Product type
# Climbing Accessories  3087       3087   3087    3087    3087      1992
# Cooking Gear          5880       5880   5880    5880    5880      4632
# First Aid             2205       2205   2205    2205    2205      1754
# Golf Accessories      1764       1764   1764    1764    1764      1764
# Insect Repellents     2205       2205   2205    2205    2205      1304
# Sleeping Bags         3087       3087   3087    3087    2867      1918
#
#                       country  Revenue  Planned  revenue  ...  sale  price.1  \
# Product type                                              ...
# Climbing Accessories      926      736      729      729  ...     0        0
# Cooking Gear             2801     2140     2061     2059  ...     0        0
# First Aid                1208      873      815      812  ...     0        0
# Golf Accessories         1306      965      902      677  ...     0        0
# ...

# %%
#11.5
#處理剩下的欄位 -- Unit cost
p1_r1_c1["Unit cost"] = p1_r1_c1["Planned"]
p1_r1_c2["Unit cost"] = p1_r1_c2["revenue"]
p1_r2_c1["Unit cost"] = p1_r2_c1["revenue"]
p1_r2_c2["Unit cost"] = p1_r2_c2['Product.3']
#############################################################
p2_r1_c1["Unit cost"] = p2_r1_c1["revenue"]
p2_r1_c2["Unit cost"] = p2_r1_c2["Product.3"]
p2_r2_c1["Unit cost"] = p2_r2_c1["Product.3"]
p2_r2_c2["Unit cost"] = p2_r2_c2["cost"]
#############################################################
p3_r1_c1["Unit cost"] = p3_r1_c1["Product.3"]
p3_r1_c2["Unit cost"] = p3_r1_c2["cost"]
p3_r2_c1["Unit cost"] = p3_r2_c1["cost"]
p3_r2_c2["Unit cost"] = p3_r2_c2["Quantity"]
#############################################################
p4_r1_c1["Unit cost"] = p4_r1_c1["cost"]
p4_r1_c2["Unit cost"] = p4_r1_c2["Quantity"]
p4_r2_c1["Unit cost"] = p4_r2_c1["Quantity"]
p4_r2_c2["Unit cost"] = p4_r2_c2["Unit"]
#############################################################
p5_r1_c1["Unit cost"] = p5_r1_c1["Quantity"]
p5_r1_c2["Unit cost"] = p5_r1_c2["Unit"]
p5_r2_c1["Unit cost"] = p5_r2_c1["Unit"]
p5_r2_c2["Unit cost"] = p5_r2_c2["cost.1"]
#############################################################
p6_r1_c1["Unit cost"] = p6_r1_c1["Unit"]
p6_r1_c2["Unit cost"] = p6_r1_c2["cost.1"]
p6_r2_c1["Unit cost"] = p6_r2_c1["cost.1"]
p6_r2_c2["Unit cost"] = p6_r2_c2["Unit.1"]
#############################################################

# %%
#11.6
#處理剩下的欄位 -- Unit price
p1_r1_c1["Unit price"] = p1_r1_c1["revenue"]
p1_r1_c2["Unit price"] = p1_r1_c2["Product.3"]
p1_r2_c1["Unit price"] = p1_r2_c1["Product.3"]
p1_r2_c2["Unit price"] = p1_r2_c2['cost']
#############################################################
p2_r1_c1["Unit price"] = p2_r1_c1["Product.3"]
p2_r1_c2["Unit price"] = p2_r1_c2["cost"]
p2_r2_c1["Unit price"] = p2_r2_c1["cost"]
p2_r2_c2["Unit price"] = p2_r2_c2["Quantity"]
#############################################################
p3_r1_c1["Unit price"] = p3_r1_c1["cost"]
p3_r1_c2["Unit price"] = p3_r1_c2["Quantity"]
p3_r2_c1["Unit price"] = p3_r2_c1["Quantity"]
p3_r2_c2["Unit price"] = p3_r2_c2["Unit"]
#############################################################
p4_r1_c1["Unit price"] = p4_r1_c1["Quantity"]
p4_r1_c2["Unit price"] = p4_r1_c2["Unit"]
p4_r2_c1["Unit price"] = p4_r2_c1["Unit"]
p4_r2_c2["Unit price"] = p4_r2_c2["cost.1"]
#############################################################
p5_r1_c1["Unit price"] = p5_r1_c1["Unit"]
p5_r1_c2["Unit price"] = p5_r1_c2["cost.1"]
p5_r2_c1["Unit price"] = p5_r2_c1["cost.1"]
p5_r2_c2["Unit price"] = p5_r2_c2["Unit.1"]
#############################################################
p6_r1_c1["Unit price"] = p6_r1_c1["cost.1"]
p6_r1_c2["Unit price"] = p6_r1_c2["Unit.1"]
p6_r2_c1["Unit price"] = p6_r2_c1["Unit.1"]
p6_r2_c2["Unit price"] = p6_r2_c2["price"]
#############################################################

# %%
#11.7
#處理剩下的欄位 -- Gross profit
p1_r1_c1["Gross profit"] = p1_r1_c1["Product.3"]
p1_r1_c2["Gross profit"] = p1_r1_c2["cost"]
p1_r2_c1["Gross profit"] = p1_r2_c1["cost"]
p1_r2_c2["Gross profit"] = p1_r2_c2['Quantity']
#############################################################
p2_r1_c1["Gross profit"] = p2_r1_c1["cost"]
p2_r1_c2["Gross profit"] = p2_r1_c2["Quantity"]
p2_r2_c1["Gross profit"] = p2_r2_c1["Quantity"]
p2_r2_c2["Gross profit"] = p2_r2_c2["Unit"]
#############################################################
p3_r1_c1["Gross profit"] = p3_r1_c1["Quantity"]
p3_r1_c2["Gross profit"] = p3_r1_c2["Unit"]
p3_r2_c1["Gross profit"] = p3_r2_c1["Unit"]
p3_r2_c2["Gross profit"] = p3_r2_c2["cost.1"]
#############################################################
p4_r1_c1["Gross profit"] = p4_r1_c1["Unit"]
p4_r1_c2["Gross profit"] = p4_r1_c2["cost.1"]
p4_r2_c1["Gross profit"] = p4_r2_c1["cost.1"]
p4_r2_c2["Gross profit"] = p4_r2_c2["Unit.1"]
#############################################################
p5_r1_c1["Gross profit"] = p5_r1_c1["cost.1"]
p5_r1_c2["Gross profit"] = p5_r1_c2["Unit.1"]
p5_r2_c1["Gross profit"] = p5_r2_c1["Unit.1"]
p5_r2_c2["Gross profit"] = p5_r2_c2["price"]
#############################################################
p6_r1_c1["Gross profit"] = p6_r1_c1["Unit.1"]
p6_r1_c2["Gross profit"] = p6_r1_c2["price"]
p6_r2_c1["Gross profit"] = p6_r2_c1["price"]
p6_r2_c2["Gross profit"] = p6_r2_c2["Gross"]
#############################################################

# %%
#11.8
#處理剩下的欄位 -- Unit sale price
p1_r1_c1["Unit sale price"] = p1_r1_c1["cost"]
p1_r1_c2["Unit sale price"] = p1_r1_c2["Quantity"]
p1_r2_c1["Unit sale price"] = p1_r2_c1["Quantity"]
p1_r2_c2["Unit sale price"] = p1_r2_c2['Unit']
#############################################################
p2_r1_c1["Unit sale price"] = p2_r1_c1["Quantity"]
p2_r1_c2["Unit sale price"] = p2_r1_c2["Unit"]
p2_r2_c1["Unit sale price"] = p2_r2_c1["Unit"]
p2_r2_c2["Unit sale price"] = p2_r2_c2["cost.1"]
#############################################################
p3_r1_c1["Unit sale price"] = p3_r1_c1["Unit"]
p3_r1_c2["Unit sale price"] = p3_r1_c2["cost.1"]
p3_r2_c1["Unit sale price"] = p3_r2_c1["cost.1"]
p3_r2_c2["Unit sale price"] = p3_r2_c2["Unit.1"]
#############################################################
p4_r1_c1["Unit sale price"] = p4_r1_c1["cost.1"]
p4_r1_c2["Unit sale price"] = p4_r1_c2["Unit.1"]
p4_r2_c1["Unit sale price"] = p4_r2_c1["Unit.1"]
p4_r2_c2["Unit sale price"] = p4_r2_c2["price"]
#############################################################
p5_r1_c1["Unit sale price"] = p5_r1_c1["Unit.1"]
p5_r1_c2["Unit sale price"] = p5_r1_c2["price"]
p5_r2_c1["Unit sale price"] = p5_r2_c1["price"]
p5_r2_c2["Unit sale price"] = p5_r2_c2["Gross"]
#############################################################
p6_r1_c1["Unit sale price"] = p6_r1_c1["price"]
p6_r1_c2["Unit sale price"] = p6_r1_c2["Gross"]
p6_r2_c1["Unit sale price"] = p6_r2_c1["Gross"]
p6_r2_c2["Unit sale price"] = p6_r2_c2["profit"]
#############################################################

# %%
#11.9 串接所有資料
p10_new = pd.concat([p1_r1_c1,p1_r1_c2,p1_r2_c1,p1_r2_c2,
                    p2_r1_c1,p2_r1_c2,p2_r2_c1,p2_r2_c2,
                    p3_r1_c1,p3_r1_c2,p3_r2_c1,p3_r2_c2,
                    p4_r1_c1,p4_r1_c2,p4_r2_c1,p4_r2_c2,
                    p5_r1_c1,p5_r1_c2,p5_r2_c1,p5_r2_c2,
                    p6_r1_c1,p6_r1_c2,p6_r2_c1,p6_r2_c2,])
p10_new
# Out:
#        Year   Product.2      Order  method    type.1   Retailer country  \
# 2500   2004  Hibernator  Telephone  Canada       NaN        NaN     NaN
# 2501   2004  Hibernator  Telephone  Mexico  26627.25   28631.85   16770
# 2502   2004  Hibernator  Telephone  Brazil       NaN        NaN     NaN
# 2503   2004  Hibernator  Telephone   Japan  624588.8  720054.32  421744
# 2504   2004  Hibernator  Telephone   Korea       NaN        NaN     NaN
# ...     ...         ...        ...     ...       ...        ...     ...
# 17529  2004      Course        Pro    Golf       and        Tee     Set
# 38682  2005      Course        Pro    Golf       and        Tee     Set
# 38697  2005      Course        Pro    Golf       and        Tee     Set
# 59850  2006      Course        Pro    Golf       and        Tee     Set
# 59865  2006      Course        Pro    Golf       and        Tee     Set
#
#       Revenue Planned revenue  ... Order method type  Retailer Country  \
# ...

# %%
#11.10 丟掉不要的欄位
p11_new = p10_new.drop(['Product.2','Order','method','type.1','Retailer','country','Revenue','Planned','revenue','Product.3','cost','Quantity','Unit','cost.1','Unit.1','price','Gross','profit','Unit.2','sale','price.1'],axis=1)

# %%
p11_new.groupby('Product type').count()
# Out:
#                       Year  Product line  Product  Order method type  \
# Product type
# Climbing Accessories  3087          3087     3087               3087
# Cooking Gear          5880          5880     5880               5880
# First Aid             2205          2205     2205               2205
# Golf Accessories      1764          1764     1764               1764
# Insect Repellents     2205          2205     2205               2205
# Sleeping Bags         3087          3087     3087               3087
#
#                       Retailer Country  Revenue.111  Planned revenue  \
# Product type
# Climbing Accessories              3087          729              729
# Cooking Gear                      5880         2059             2059
# First Aid                         2205          812              812
# Golf Accessories                  1764          619              619
# Insect Repellents                 2205          795              795
# ...

# %%
p11_new = p11_new.drop('Revenue.111',axis=1)

# %%
p11_new = p11_new.rename(columns={'Revenue.111': 'Revenue','Quantity.111': 'Quantity'})

# %%
#11 整理完成
p11_new
# Out:
#        Year       Product line      Product type                      Product  \
# 2500   2004  Camping Equipment     Sleeping Bags                   Hibernator
# 2501   2004  Camping Equipment     Sleeping Bags                   Hibernator
# 2502   2004  Camping Equipment     Sleeping Bags                   Hibernator
# 2503   2004  Camping Equipment     Sleeping Bags                   Hibernator
# 2504   2004  Camping Equipment     Sleeping Bags                   Hibernator
# ...     ...                ...               ...                          ...
# 17529  2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 38682  2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 38697  2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 59850  2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 59865  2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
#
# ...

# %%
#12 輸出csv
p11_new.to_csv('ECT_HW1_108403523.csv', index=True)

# %%
#13 驗證資料個數正確
p11_new.groupby('Product type').count()
# Out:
#                       Year  Product line  Product  Order method type  \
# Product type
# Climbing Accessories  3087          3087     3087               3087
# Cooking Gear          5880          5880     5880               5880
# First Aid             2205          2205     2205               2205
# Golf Accessories      1764          1764     1764               1764
# Insect Repellents     2205          2205     2205               2205
# Sleeping Bags         3087          3087     3087               3087
#
#                       Retailer Country  Planned revenue  Product cost  \
# Product type
# Climbing Accessories              3087              729           729
# Cooking Gear                      5880             2059          2059
# First Aid                         2205              812           812
# Golf Accessories                  1764              619           619
# Insect Repellents                 2205              795           795
# ...
